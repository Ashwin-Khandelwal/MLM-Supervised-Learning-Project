# %% [markdown]
# # **Supervised Learning Models on Import-Export Dataset using Python**
#
#
#
# ---
#
#
#
# ## **PROJECT CONTENTS:**
# - Project Information
# - Description of Data
# - Data Sampling
# - Project Objectives | Problem Statements
# - Analysis of Data
# - Observations | Findings
# - Managerial Insights | Recommendations
#
# ---
#
# ### **1. Project Information**
# - **Title**: Building Supervised Learning Models using Python: Classification & Regression {Logistic Regression | Decision Trees}
# - **Student Name**: Ashwin Khandelwal (055008)
#
# ---
#
# ### **2. Description of Data**
# - **Data Source**: https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000
#
#   A live link is used in the dataset
#
# - **Data Columns Description**:
#   - **Transaction_ID**: Unique identifier for each trade transaction.
#   - **Country**: Country of origin or destination for the trade.
#   - **Product**: Product being traded.
#   - **Import_Export**: Indicates whether the transaction is an import or export.
#   - **Quantity**: Amount of the product traded.
#   - **Value**: Monetary value of the product in USD.
#   - **Date**: Date of the transaction.
#   - **Category**: Category of the product (e.g., Electronics, Clothing, Machinery).
#   - **Port**: Port of entry or departure.
#   - **Customs_Code**: Customs or HS code for product classification.
#   - **Weight**: Weight of the product in kilograms.
#   - **Shipping_Method**: Method used for shipping (e.g., Air, Sea, Land).
#   - **Supplier**: Name of the supplier or manufacturer.
#   - **Customer**: Name of the customer or recipient.
#   - **Invoice_Number**: Unique invoice number for the transaction.
#   - **Payment_Terms**: Terms of payment (e.g., Net 30, Net 60, Cash on Delivery).
#
# - **Data Type**: Since the dataset contains multiple entities (countries) and records data over time, this is an example of Panel Data (also called longitudinal data).
#
# - **Data Variables**:
#   - **All non-null Variables**
#     - **Numbers**:
#       - Integer Variables: 3 (Quantity, Customs_Code, Invoice_Number)
#       - Float (Decimal) Variables: 2 (Value, Weight)
#     - **Text**: 9 (Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customer, Payment_Terms)
#     - **DateTime**: 1 (Date)
#
# ---
#
# ### **3. Data Sampling**
# From the dataset containing 15,000 values, a sample of 5001 entries was taken. The dataset sample (now referred to as `ak08_sample`) was taken into account for further exploration.
#
# - **Data Variables**:
#   - **Index Variables**: 'Transaction_ID', 'Invoice_Number'
#   - **Categorical Variables**:
#     - Nominal Variables: Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customs_Code, Customer
#     - Ordinal Variable: Payment_Terms
#   - **Non-Categorical Variables**: Quantity, Value, and Weight
#
# ---
#
# ### **4. Project Objectives**
# - Classification of Dataset into {Segments | Clusters | Classes} using Supervised Learning Classification Algorithms
# - Identification of {Important | Contributing | Significant} Variables or Features and their Thresholds for Classification
# - Determination of an appropriate Classification Model based on Performance Metrics
#
#
# ---
#
# ### **5. Exploratory Data Analysis**
# #### **5.1. Data Preprocessing:**
# - The data has no missing values, hence no missing data treatment was performed.
# - For Encoding, **Ordinal Encoder** was used.
# - For Scaling, **Min-Max Scaler** was used.
#
# #### **5.2. Descriptive Statistics**
# - **Non-Categorical Variables**:
#   - Measures of Central Tendency: Minimum, Maximum, Mean, Median, Mode, Percentile
#   - Measures of Dispersion: Range, Standard Deviation, Skewness, Kurtosis, Correlation (Matrix)
#   - Composite Measure: Coefficient of Variation, Confidence Interval
#
# - **Categorical Variables**:
#   - Count, Frequency, Proportion, Minimum, Maximum, Mode, Rank
#
# #### **5.3. Data Visualization**
# - Various subplots were used such as Bar, Heatmaps, Histograms, and Correlation Matrices.
#
# #### **5.4. Inferential Statistics**
# - **Categorical Variable** (Nominal | Ordinal):
#   - Test of Homogeneity (Chi-sq)
# - **Non-Categorical Variable**:
#   - Test of Normality (Shapiro-Wilk, Kolmogorov-Smirnov, Anderson-Darling, Jarque-Bera)
#   - Test of Correlation (t)
#
# #### **5.5. Machine Learning Models**
#
# - **Logistic Regression (LR)**:
#   Logistic regression is a classification algorithm that models the probability of a binary outcome based on one or more predictor variables using a logistic function.
#
# - **Support Vector Machines (SVM)**:
#   SVM finds a hyperplane that best separates the data into classes by maximizing the margin between the closest points of the classes (support vectors).
#
# - **Stochastic Gradient Descent (SGD)**:
#   An iterative optimization algorithm used for minimizing loss functions in linear classifiers and regressors, particularly useful for large datasets.
#
# - **Decision Trees**:
#   A tree-based algorithm where each internal node represents a decision on a feature, each leaf node represents an outcome, and paths from root to leaf represent classification rules.
#
# - **K-Nearest Neighbors (KNN)**:
#   A lazy learning algorithm that classifies a data point based on the majority class of its k-nearest neighbors in the feature space.
#
# - **Naive Bayes (NB)**:
#   A probabilistic classifier based on Bayes' theorem, assuming strong independence between features.
#
# - **Bagging (Bootstrap Aggregating)**:
#   Combines predictions from multiple models (e.g., Random Forest) to reduce variance and improve accuracy.
#
# - **Boosting**:
#   Combines weak learners sequentially to form a strong learner by minimizing errors iteratively (e.g., Extreme Gradient Boosting - XGBoost).
#
# #### **5.6. Model Performance Metrics**
#
# - **Confusion Matrix**:
#   - Sensitivity (Recall): True Positive Rate
#   - Specificity: True Negative Rate
#   - Accuracy: Overall correctness
#   - Precision: Positive Predictive Value
#   - F1-Score: Harmonic mean of Precision and Recall
#   - AUC: Area Under the ROC Curve
#
# - **K-Fold Cross-Validation**: Splits data into k subsets; trains on k-1 and tests on the remaining one iteratively to ensure robust performance evaluation.
#
# - **Model Run Statistics**:
#   - Time Taken
#   - Memory Used
# ---
#
#
# ### **6. Observations and Findings**
#
# #### **6.1. Nature of Data**
# - **Missing Data**: The dataset contained no missing values.
# - **Non-Numeric Categorical Data**: Categorical variables (e.g., Country, Product) were encoded using ordinal encoding.
# - **Scales and Outliers**:
#   - Non-categorical numeric data (Quantity, Value, Weight) were scaled using Min-Max scaling.
#   - Box plots revealed potential outliers, but they were not removed as they might hold valuable information.
#
# #### **6.2. Supervised Machine Learning: Classification & Regression**
#
# **> Determination of Appropriate Classification Model:**
#
# **LR vs. SGD:**
# - Performance Metrics: Looking at accuracy scores, Logistic Regression (33.24%) performed slightly better than SGD (32.91%).
# - Run Statistics: The comparison shows Logistic Regression has better accuracy with a difference of about 0.33%.
# - Conclusion: Based on the accuracy metrics, Logistic Regression performs marginally better than SGD for this dataset.
#
# **DT vs. KNN:**
# - Performance Metrics: Decision Tree achieved an accuracy of 31.85%, while KNN showed slightly better performance with 32.71% accuracy.
# - Run Statistics: The comparison clearly indicates that KNN outperforms Decision Tree with a difference of about 0.86%.
# - Conclusion: For this dataset, K Nearest Neighbour model demonstrates better classification performance compared to Decision Tree.
#
# **LR vs. DT:**
# - Performance Metrics: Logistic Regression achieved 33.24% accuracy while Decision Tree showed 31.85% accuracy.
# - Run Statistics: The comparison shows that Logistic Regression outperforms Decision Tree by approximately 1.39%.
# - Conclusion: Based on the accuracy metrics, Logistic Regression model demonstrates better classification performance for this dataset.
#
# **DT vs. NB:**
# - Performance Metrics: Decision Tree achieved 31.85% accuracy while Naive Bayes performed better with 33.71% accuracy.
# - Run Statistics: The comparison indicates that Naive Bayes outperforms Decision Tree by approximately 1.86%.
# - Conclusion: For this particular dataset, Naive Bayes model shows superior classification performance compared to Decision Tree.
#
# **> Cross-Validation of Results and Performance:**
#
# **Logistic Regression**
# - K-Fold Cross-Validation Accuracy Scores: [0.32714286 0.33142857 0.35142857 0.33142857 0.33857143]
# - Mean Accuracy: 0.3359
# - Standard Deviation of Accuracy: 0.00854
# - Test Set Accuracy: 0.3324
# - Classification Metrics on Test Set:
# - Precision:
#     - Class 0: 0.32
#     - Class 1: 0.35
#     - Class 2: 0.15
# - Recall:
#     - Class 0: 0.55
#     - Class 1: 0.46
#     - Class 2: 0.00
# - F1-Score:
#     - Class 0: 0.41
#     - Class 1: 0.40
#     - Class 2: 0.01
# - Weighted Avg:
#     - Precision: 0.27
#     - Recall: 0.33
#     - F1-Score: 0.27
#
# **Observations:** Logistic Regression performed moderately, with a mean cross-validation accuracy of 33.59% and a test set accuracy of 33.24%. However, the model struggles with Class 2 (0% recall), while achieving good recall (55%) for Class 0.
#
# **Support Vector Machine (SVM)**
#
# K-Fold Cross-Validation Accuracy Scores: [0.33, 0.33571429, 0.33142857, 0.34571429, 0.33]
# Mean Accuracy: 0.3345714285714286
# Standard Deviation of Accuracy: 0.005952190473142749
# Test Set Accuracy: 0.3344437041972019
#
# --Classification Metrics on Test Set:**
# - Precision:
#   - Class 0: 0.33
#   - Class 1: 0.34
#   - Class 2: 0.00
# - Recall:
#   - Class 0: 0.53
#   - Class 1: 0.49
#   - Class 2: 0.00
# - F1-Score:
#   - Class 0: 0.40**
#   - Class 1: 0.41**
#   - Class 2: 0.00**
# - Weighted Avg:**
#   - Precision: 0.22**
#   - Recall: 0.33**
#   - F1-Score: 0.26**
#
# **Observations:** The SVM model demonstrates a modest mean cross-validation accuracy of 33.46% with a standard deviation of 0.006.The test set accuracy of 33.44% is consistent with the cross-validation results. The model exhibits a slight class imbalance, with a higher recall for Class 0 (0.53) and Class 1 (0.49) compared to Class 2 (0.00). However, the precision for Class 2 is low (0.00), indicating that the model often misclassifies instances into Class 2. Overall, the SVM model's performance is relatively poor, suggesting the need for further model exploration or data preprocessing.
#
#
# **Stochastic Gradient Descent (SGD)**
# - K-Fold Cross-Validation Accuracy Scores: [0.35, 0.34, 0.30285714, 0.32857143, 0.35285714]
# - Mean Accuracy: 0.33485714285714285
# - Standard Deviation of Accuracy: 0.01812879094767463
# - Test Set Accuracy: 0.3291139240506329
# - Classification Metrics on Test Set:
# - Precision:
#    - Class 0: 0.00
#    - Class 1: 0.33
#    - Class 2: 0.00
# - Recall:
#    - Class 0: 0.00
#    - Class 1: 1.00
#    - Class 2: 0.00
# - F1-Score:
#    - Class 0: 0.00
#    - Class 1: 0.50
#    - Class 2: 0.00
# - Weighted Avg:
#    - Precision: 0.11
#    - Recall: 0.33
#    - F1-Score: 0.16
#
# **Observations:** SGD achieved a mean cross-validation accuracy of 33.49% with a standard deviation of 0.018. The test set accuracy is 32.91%. Unlike the previous text, the model completely fails to classify Classes 0 and 2, focusing solely on Class 1 with perfect recall but low precision of 0.33, resulting in an F1-score of 0.50 for Class 1.
#
# **Model-Specific Observations and Insights**
#
# **Decision Tree**
#
# - Accuracy: 32% (low).
# - Key Variables: Country, Product, Quantity, and Value consistently influence splits in the decision tree.
# - Misclassifications:
#   Significant confusion between Cluster 0 and Cluster 1.
#   Slightly better precision, recall, and F1-score for Class 2.0, suggesting better performance in distinguishing specific clusters.
#
# **Thresholds:**
# Products with higher Value and lower Weight are better identified.
# Quantity thresholds can differentiate bulk vs. specialized goods.
#
# **Random Forest**
#
# - Accuracy: 32% (similar to Decision Tree).
# - Key Variables: Similar to Decision Tree but with more robust handling of non-linear relationships.
# - Insights:
#   Strong influence of features like Port and Customs_Code due to ensemble averaging.
#   Suggested thresholds include grouping Ports based on traffic volume.
#
# **XGBoost**
#
# - Accuracy: 33% (low).
# - Key Variables: Product, Country, and Value show importance based on feature weights.
# - Insights:
#   Performance is hindered by imbalanced data; sampling or scaling thresholds for major features like Value may improve accuracy.
#
# **KNN**
#
# - Accuracy: 33% (low).
# - Key Variables: Quantity and Weight, as KNN depends heavily on distance-based relationships.
# - Insights:
#   Data normalization could improve clustering based on these variables.
#
# **Naive Bayes**
#
# - Accuracy: 34% (low).
# - Key Variables: Import_Export, Customs_Code, and Shipping_Method.
# - Insights:
#   Limited by assumptions of independence, but categorical variables like Import_Export and Customs_Code drive predictions.
#
# **Logistic Regression**
#
# - Accuracy: 33% (low).
# - Key Variables: Country, Product, and Shipping_Method.
# - Insights:
#   Fails completely for Cluster 2 due to class imbalance or overlapping data.
#   Threshold refinement for categorical features like Shipping_Method could help separate clusters.
#
# ---
#
# ### **7. Managerial Insights and Recommendations**
#
# #### **7.1. Preprocessing of Data**
# - **Missing Data**: No specific treatment is necessary due to the absence of missing data.
# - **Encoding**: Ordinal encoding proved effective for categorical variables.
# - **Scaling**: Min-Max scaling was appropriate to address potential scale differences.
# - **Data Split**: A **70:30 split** for training and testing sets would be appropriate for future supervised learning tasks.
#
# #### **7.2. Supervised Machine Learning: Classification & Regression**
#
# **Inference regarding the Purpose of Classification:**
#
# The purpose of classification is to analyze trade data and identify patterns or clusters in transactions based on variables such as country, product, trade type, and other attributes. These patterns aim to inform strategic decision-making for efficient trade management, including optimizing shipping methods, targeting specific trade partners, and identifying product segments for growth.
#
# **Logistic Regression (LR)**
#
# - **Recommendation of Key Features and their Thresholds:**
#   - **Country:** Focus on trade patterns from top trading partners based on transaction counts or values.
#   - **Shipping_Method:** Prioritize air shipments for lightweight, high-value items.
#   - **Product:** Highlight product categories with distinct thresholds, e.g., electronics and machinery for high-value items.
#   - **Thresholds:** Products with higher value and lower weight should be emphasized for classification.
#
# - **Insight on its Uniqueness, Usability, and Suitability:**
#   Logistic Regression is unique for its simplicity and interpretability. It performs well with binary classification and linear relationships. It is suitable for datasets with well-separated classes but struggles with imbalanced datasets. Its fast runtime makes it usable for quick analysis, but further optimization is needed to improve accuracy.
#
# **Support Vector Machine (SVM)**
#
# - **Recommendation of Key Features and their Thresholds:**
#   - **Product:** Target clusters of products with extreme thresholds, such as high-value electronics.
#   - **Weight:** Prioritize lightweight items for Class 2, where SVM performs best.
#   - **Country:** Focus on countries with high export or import volumes.
#   - **Thresholds:** Assign products with lightweight and high value to distinct clusters for better classification.
#
# - **Insight on its Uniqueness, Usability, and Suitability:**
#   SVM is unique for its ability to handle non-linear boundaries and high-dimensional spaces. It is suitable for datasets with distinct class separations but less usable for imbalanced data due to its bias toward the dominant class. Its long runtime and memory inefficiency make it less practical for this dataset.
#
# **Stochastic Gradient Descent (SGD)**
#
# - **Recommendation of Key Features and their Thresholds:**
#   - **Quantity and Value:** Use high-value thresholds to improve classification for specific clusters.
#   - **Import_Export:** Emphasize export data for lightweight, high-value items.
#   - **Country:** Highlight key trade partners to distinguish high-transaction clusters.
#
# - **Insight on its Uniqueness, Usability, and Suitability:**
#   SGD is unique in its ability to handle large-scale datasets and iterative optimization. It is usable for linear classification problems but struggles with imbalanced datasets. Its suitability depends on regularization techniques and tuning, which can improve model performance.
#
# **Decision Tree (DT)**
#
# - **Recommendation of Key Features and their Thresholds:**
#   - **Country:** Strong correlation with trade clusters; prioritize high-volume trade partners.
#   - **Product and Value:** Split data based on thresholds like product categories and high-value items.
#   - **Customs_Code:** Use categorical splits to differentiate trade classifications.
#
# - **Insight on its Uniqueness, Usability, and Suitability:**
#   Decision Tree models are unique for their interpretability and ability to capture non-linear relationships. They are suitable for categorical and numerical data with clear thresholds. While they are usable for this dataset, they may require pruning or ensemble methods to avoid overfitting.
#
# **K-Nearest Neighbors (KNN)**
#
# - **Recommendation of Key Features and their Thresholds:**
#   - **Quantity and Weight:** Normalize these features to improve distance-based relationships.
#   - **Shipping_Method:** Group transactions based on shipping preferences (air for lightweight, high-value goods).
#   - **Thresholds:** Focus on lightweight, high-value products for distinct clustering.
#
# - **Insight on its Uniqueness, Usability, and Suitability:**
#   KNN is unique for its simplicity and reliance on distance metrics. It is usable for small datasets with well-defined clusters but requires careful normalization and feature scaling. Its fast runtime makes it suitable for initial analysis, but it is less efficient for large datasets.
#
# **Random Forest (RF)**
#
# - **Recommendation of Key Features and their Thresholds:**
#   - **Port and Customs_Code:** Emphasize high-traffic ports and major trade categories for classification.
#   - **Product and Value:** Focus on thresholds that differentiate product categories by value and trade volume.
#
# - **Insight on its Uniqueness, Usability, and Suitability:**
#   Random Forest is unique for its robustness and ability to reduce overfitting through ensemble learning. It is highly usable for datasets with non-linear relationships and categorical variables. Its higher memory usage and runtime, however, may limit its practicality for time-sensitive tasks.
#
# **General Recommendation:**
#
# Considering the low accuracy across all models, the dataset may benefit from:
# - **Feature Engineering:** Refining and scaling numerical variables like quantity and value.
# - **Class Imbalance Handling:** Using techniques like oversampling, undersampling, or synthetic data generation (SMOTE).
# - **Model Optimization:** Tuning hyperparameters and testing ensemble methods to improve overall accuracy.
# - **Alternative Approaches:** Exploring clustering methods like k-means for unsupervised analysis or advanced algorithms like neural networks for non-linear relationships.

# %% [markdown]
# ##**Project Information and Analysis**

# %%
# Import Relevant Python Libraries

from io import StringIO
import requests
import pandas as pd
import statsmodels.formula.api as sm
from scipy.stats import chi2_contingency
from scipy.stats import shapiro, kstest, anderson, jarque_bera
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN, Birch
from scipy.cluster.hierarchy import dendrogram, linkage
import statsmodels.stats.descriptivestats as dstats
import numpy as np  # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder  # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.impute import SimpleImputer, KNNImputer  # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler  # For Rescaling Data
from sklearn.model_selection import train_test_split  # For Splitting Data into Training & Testing Sets
import matplotlib.pyplot as plt
import seaborn as sns  # For Data Visualization
import scipy.cluster.hierarchy as sch  # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus  # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score,davies_bouldin_score  # For Clustering Model Evaluation
import statsmodels.api as sm
from sklearn import metrics
import scipy.stats as stats
import statsmodels.stats.multicomp as multi
import warnings
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score



warnings.filterwarnings('ignore')

# %%
# Replace with your actual file ID
file_id = '1F6j4DkSVdF-36nxvLiDLu1qOE9lHhzcC'

# Construct the URL
url = f'https://drive.google.com/uc?id={file_id}'  #using f-string (format string)

# Fetch the data using requests
response = requests.get(url)
response.raise_for_status()  # Raise an exception for bad responses

# Read the data into a pandas DataFrame using StringIO
ak08_df = pd.read_csv(StringIO(response.text))

# %%
# Data Dimensions
print("The dimensions of the data is: ",ak08_df.shape)
# Out:
# The dimensions of the data is:  (15000, 16)

# %%
# Data Variable Type
ak08_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   15000 non-null  object
#  1   Country          15000 non-null  object
#  2   Product          15000 non-null  object
#  3   Import_Export    15000 non-null  object
#  4   Quantity         15000 non-null  int64
#  5   Value            15000 non-null  float64
#  6   Date             15000 non-null  object
#  7   Category         15000 non-null  object
#  8   Port             15000 non-null  object
#  9   Customs_Code     15000 non-null  int64
#  10  Weight           15000 non-null  float64
#  11  Shipping_Method  15000 non-null  object
#  12  Supplier         15000 non-null  object
#  13  Customer         15000 non-null  object
#  14  Invoice_Number   15000 non-null  int64
#  15  Payment_Terms    15000 non-null  object
# ...

# %%
# Bifurcating the Variables into Index, Categorical (Nominal, Ordinal) and Non-Categorical Variables

ak08_index_vars=['Transaction_ID','Invoice_Number']
ak08_nominal_vars=[ 'Country','Product','Import_Export','Category','Port','Shipping_Method','Supplier','Customer','Customs_Code']
ak08_ordinal_vars=['Payment_Terms']

ak08_cat_vars= ak08_nominal_vars + ak08_ordinal_vars
ak08_non_cat_vars=['Quantity','Value','Weight']

# %% [markdown]
# ## **Taking a Unique Sample of 5001 Records**

# %%
ak08_sample = pd.DataFrame.sample(ak08_df, n=5001, random_state=55008 ,ignore_index=False)
# Displaying the Dimensions of Sample Data.
ak08_sample.shape
# Out:
# (5001, 16)

# %% [markdown]
# ## **Data Pre-Processing**

# %%
ak08_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5001 entries, 6523 to 6588
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   5001 non-null   object
#  1   Country          5001 non-null   object
#  2   Product          5001 non-null   object
#  3   Import_Export    5001 non-null   object
#  4   Quantity         5001 non-null   int64
#  5   Value            5001 non-null   float64
#  6   Date             5001 non-null   object
#  7   Category         5001 non-null   object
#  8   Port             5001 non-null   object
#  9   Customs_Code     5001 non-null   int64
#  10  Weight           5001 non-null   float64
#  11  Shipping_Method  5001 non-null   object
#  12  Supplier         5001 non-null   object
#  13  Customer         5001 non-null   object
#  14  Invoice_Number   5001 non-null   int64
#  15  Payment_Terms    5001 non-null   object
# dtypes: float64(2), int64(3), object(11)
# ...

# %%
# Check for missing values

ak08_sample.isnull().sum(axis=1)
# Out:
# 6523     0
# 5619     0
# 8335     0
# 8635     0
# 1169     0
#         ..
# 12899    0
# 10463    0
# 9177     0
# 12981    0
# 6588     0
# Length: 5001, dtype: int64

# %% [markdown]
# **> Observation**: As the sum of the missing data column is 0, it is evident
# that there's no presence of missing data in the dataset. So the process of missing data treatment is skipped.

# %%
# Encoding

ak08_oe = OrdinalEncoder()
ak08_categorical_cols = ak08_sample[ak08_cat_vars]
ak08_oe_fit = ak08_oe.fit_transform(ak08_categorical_cols)
ak08_encoded = pd.DataFrame(ak08_oe_fit, columns=ak08_cat_vars)
ak08_encoded.head()
# Out:
#    Country  Product  Import_Export  Category    Port  Shipping_Method  \
# 0     32.0    784.0            1.0       4.0  2897.0              2.0
# 1    107.0    331.0            1.0       1.0   671.0              1.0
# 2    170.0     54.0            0.0       3.0  2521.0              1.0
# 3    183.0     35.0            1.0       4.0   444.0              0.0
# 4     52.0    454.0            0.0       3.0  1160.0              2.0
#
#    Supplier  Customer  Customs_Code  Payment_Terms
# 0    3750.0    1679.0        1865.0            2.0
# 1     347.0    3050.0         239.0            2.0
# 2     576.0    4047.0        3590.0            0.0
# 3    1132.0    4044.0        3129.0            3.0
# 4     313.0    1697.0        1069.0            3.0

# %%
#Scaling

ak08_scaler = MinMaxScaler()
ak08_scaled_data = ak08_scaler.fit_transform(ak08_sample[ak08_non_cat_vars])
ak08_scaled = pd.DataFrame(ak08_scaled_data, columns=ak08_non_cat_vars)
ak08_scaled.head()
# Out:
#    Quantity     Value    Weight
# 0  0.349910  0.397253  0.094582
# 1  0.689214  0.636300  0.298642
# 2  0.803182  0.308072  0.761661
# 3  0.662598  0.996850  0.214661
# 4  0.520112  0.930252  0.106214

# %%
# The pre-processed Dataset
ak08_processed = pd.concat([ak08_scaled, ak08_encoded], axis=1)
ak08_processed.head()

ak08_sample = ak08_processed
ak08_sample.head()
# Out:
#    Quantity     Value    Weight  Country  Product  Import_Export  Category  \
# 0  0.349910  0.397253  0.094582     32.0    784.0            1.0       4.0
# 1  0.689214  0.636300  0.298642    107.0    331.0            1.0       1.0
# 2  0.803182  0.308072  0.761661    170.0     54.0            0.0       3.0
# 3  0.662598  0.996850  0.214661    183.0     35.0            1.0       4.0
# 4  0.520112  0.930252  0.106214     52.0    454.0            0.0       3.0
#
#      Port  Shipping_Method  Supplier  Customer  Customs_Code  Payment_Terms
# 0  2897.0              2.0    3750.0    1679.0        1865.0            2.0
# 1   671.0              1.0     347.0    3050.0         239.0            2.0
# 2  2521.0              1.0     576.0    4047.0        3590.0            0.0
# 3   444.0              0.0    1132.0    4044.0        3129.0            3.0
# 4  1160.0              2.0     313.0    1697.0        1069.0            3.0

# %% [markdown]
# ## **Descriptive Statistics**
#
# ### **1. Non-Categorical Variables**

# %%
ak08_sample[ak08_non_cat_vars].describe()
# Out:
#           Quantity        Value       Weight
# count  5001.000000  5001.000000  5001.000000
# mean      0.496262     0.498111     0.498434
# std       0.286902     0.286618     0.288930
# min       0.000000     0.000000     0.000000
# 25%       0.246548     0.249583     0.249408
# 50%       0.493596     0.499193     0.499726
# 75%       0.741945     0.743541     0.749904
# max       1.000000     1.000000     1.000000

# %% [markdown]
# #### **> Observations:**
#
# **Central Tendency:** The mean values for Quantity, Value, and Weight are all centered around 0.5, indicating a balanced distribution after Min-Max scaling.
#
# **Similar Variability:** The standard deviation for all three variables is around 0.29 (approx., after rounding up), signifying moderate data dispersion.
#
# **Scaled Data:** The minimum and maximum values of 0 and 1 respectively confirm the data has been normalized using Min-Max scaling.

# %%
def summarize_numerical(my_sample, variables):
    summary = {}

    for col in variables:
        if col in ak08_sample[ak08_non_cat_vars]:  # Check if the column exists in the DataFrame
            summary[col] = {
                'Mode': my_sample[col].mode()[0],
                'Range': my_sample[col].max() - my_sample[col].min(),
                'Skewness': my_sample[col].skew() ,
                'Kurtosis': my_sample[col].kurtosis()
            }
    return summary

# %%
summary_stats = summarize_numerical(ak08_sample,ak08_non_cat_vars)
summary_df = pd.DataFrame.from_dict(summary_stats, orient='index')
summary_df
# Out:
#               Mode  Range  Skewness  Kurtosis
# Quantity  0.218331    1.0  0.022264 -1.184072
# Value     0.005314    1.0  0.018216 -1.181983
# Weight    0.110344    1.0  0.011217 -1.200006

# %% [markdown]
# #### **> Observations:**
#
# **Range:**
# All three variables (Quantity, Value, Weight) exhibit a range of 1.0. This confirms that Min-Max scaling has effectively normalized the data to cover the entire range from 0 to 1, maximizing variability utilization.
#
# **Skewness:**
# Skewness values for Quantity, Value, and Weight are close to zero. This indicates near-symmetric distributions, suggesting a balanced frequency of observations on both sides of the average, with a potential slight positive skew.
#
# **Kurtosis:**
# Kurtosis values for all three variables are negative. This implies platykurtic distributions, meaning the data has fewer extreme values or outliers compared to a normal distribution, resulting in a flatter peak.

# %%
# Coefficient of Variation
def coefficient_of_variation(data):
    mean = data.mean()
    std = data.std()
    cv = (std / mean) * 100
    return cv

cv_results = {}

for col in ak08_non_cat_vars:
    cv_results[col] = coefficient_of_variation(ak08_sample[col])

# Display the results
print("Coefficient of Variation (%):")
for col, cv in cv_results.items():
    print(f"{col}: {cv:.2f}%")
# Out:
# Coefficient of Variation (%):
# Quantity: 57.81%
# Value: 57.54%
# Weight: 57.97%

# %% [markdown]
# ####**> Observations:**
#
# **Quantity:**
#
# - Quantity has a CV of 57.81%.
# - This indicates moderate variability or dispersion in the quantity of products traded relative to the mean quantity.
#
# **Value:**
#
# - Value shows a CV of 57.54%.
# - This suggests a moderate level of variability in the monetary value of transactions compared to the average transaction value.
#
# **Weight:**
#
# - Weight exhibits a CV of 57.97%.
# - This signifies moderate variability in the weight of products traded relative to the mean weight, potentially reflecting product diversity.

# %%
# Confidence Interval for the Mean
def confidence_interval(data, confidence=0.95):
    mean = data.mean()
    std = data.std()
    n = len(data)
    z = stats.norm.ppf(1 - (1 - confidence) / 2)  # z-score for 95% CI
    margin_of_error = z * (std / np.sqrt(n))
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error
    return (lower_bound, upper_bound)

ci_results = {}
for col in ak08_non_cat_vars:
    ci_results[col] = confidence_interval(ak08_sample[col])


print("\nConfidence Intervals (95%):")
for col, ci in ci_results.items():
    print(f"{col}: {ci[0]:.2f} to {ci[1]:.2f}")
# Out:
# Confidence Intervals (95%):
# Quantity: 0.49 to 0.50
# Value: 0.49 to 0.51
# Weight: 0.49 to 0.51

# %% [markdown]
# ####**> Observations:**
#
# **Quantity:**
#
# - The 95% CI for Quantity is 0.49 to 0.50.
# - This narrow interval suggests high precision in estimating the true population mean of Quantity, indicating a likely centralized distribution around 0.5.
#
# **Value:**
#
# - The 95% CI for Value is 0.49 to 0.51.
# - This slightly wider interval compared to Quantity implies a marginally higher uncertainty in estimating the population mean of Value, but still indicates a relatively centralized distribution.
#
# **Weight:**
#
# - The 95% CI for Weight is 0.49 to 0.51.
# - Similar to Value, this interval reflects moderate certainty in estimating the population mean of Weight and a likely centralized distribution around 0.5.

# %%
correlation_data = ak08_sample[ak08_non_cat_vars]
correlation_matrix = correlation_data.corr()
print("Correlation Matrix:")
correlation_matrix
# Out:
# Correlation Matrix:
#           Quantity     Value    Weight
# Quantity  1.000000  0.000011  0.014773
# Value     0.000011  1.000000  0.011504
# Weight    0.014773  0.011504  1.000000

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ####**> Observations:**
#
# **Quantity and Value:**
# The correlation coefficient is 1.1e-0.5, indicating an almost negligible negative relationship.
#
# **Quantity and Weight:**
# The correlation coefficient is 0.015, showing a very weak positive relationship.
#
# **Value and Weight:**
# The correlation coefficient is 0.012, signifying an almost non-existent positive relationship.

# %% [markdown]
# ### **2. Categorical Variables**

# %%
# Categorical Data

def ak08_categorical_summary(df, cat_cols):
    summary = {}
    for col in cat_cols:
        if col in df.columns:
            summary[col] = {
                'Count': df[col].count(),
                'Minimum': df[col].min(),
                'Maximum': df[col].max(),
                'Mode': df[col].mode().iloc[0],
            }
    return summary

ak08_categorical_summaries = ak08_categorical_summary(ak08_sample, ak08_cat_vars)

for col, stats in ak08_categorical_summaries.items():
    print(f"Summary for {col}:")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value}")
    print("-" * 20)  # separator
# Out:
# Summary for Country:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 242.0
#   Mode: 49.0
# --------------------
# Summary for Product:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 964.0
#   Mode: 182.0
# --------------------
# Summary for Import_Export:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 1.0
#   Mode: 1.0
# --------------------
# Summary for Category:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4.0
#   Mode: 3.0
# --------------------
# Summary for Port:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4238.0
#   Mode: 4075.0
# --------------------
# Summary for Shipping_Method:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 2.0
#   Mode: 2.0
# --------------------
# Summary for Supplier:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4584.0
#   Mode: 2018.0
# --------------------
# Summary for Customer:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4822.0
#   Mode: 162.0
# --------------------
# Summary for Customs_Code:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4979.0
# ...

# %% [markdown]
# ## **Data Visualization**

# %%
# Box plots for non-categorical variables

plt.figure(figsize=(15, 10))
for i, col in enumerate(ak08_non_cat_vars):
    plt.subplot(2, 3, i + 1)
    sns.boxplot(y=ak08_sample[col])
    plt.title(f'Box Plot of {col}')
plt.tight_layout()
plt.show()

# %%
# Histograms with KDE for distribution visualization
plt.figure(figsize=(15, 10))
for i, col in enumerate(ak08_non_cat_vars):
    plt.subplot(2, 3, i + 1)
    sns.histplot(ak08_sample[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
# Violin Plot

sns.violinplot(x='Category', y='Quantity', data=ak08_sample)
plt.title('Distribution of Quantity across Categories')
plt.show()

# %% [markdown]
# ## **Inferential Statistics**

# %%
# Test of Homogeneity {Chi-sq} on categorical data

ak08_contingency_table = pd.crosstab(ak08_sample['Import_Export'], ak08_sample['Category'])

# Perform the Chi-square test
chi2, p, dof, expected = chi2_contingency(ak08_contingency_table)

print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

# Interpret the results
ak08_alpha = 0.05  # Significance level

if p < ak08_alpha:
    print("Reject the null hypothesis: There is a significant association between the two categorical variables.")
else:
    print("There is no significant association between the two categorical variables.")
# Out:
# Chi-square statistic: 2.5207400885818916
# P-value: 0.640925849603734
# Degrees of freedom: 4
# Expected frequencies:
# [[475.77364527 486.58668266 496.41671666 508.21275745 491.01019796]
#  [492.22635473 503.41331734 513.58328334 525.78724255 507.98980204]]
# There is no significant association between the two categorical variables.

# %%
# Test of Normality {Shapiro-Wilk | Kolmogorov-Smirnov | Anderson-Darling | Jarque-Bera

def normality_tests(data):

    ak08_results = {}

    # Shapiro-Wilk test
    shapiro_statistic, shapiro_pvalue = shapiro(data)
    ak08_results["Shapiro-Wilk"] = {"statistic": shapiro_statistic, "p-value": shapiro_pvalue}

    # Kolmogorov-Smirnov test (against a normal distribution)
    ks_statistic, ks_pvalue = kstest(data, 'norm')
    ak08_results["Kolmogorov-Smirnov"] = {"statistic": ks_statistic, "p-value": ks_pvalue}

    # Anderson-Darling test
    anderson_result = anderson(data)
    ak08_results["Anderson-Darling"] = {
        "statistic": anderson_result.statistic,
        "critical_values": anderson_result.critical_values,
        "significance_level": anderson_result.significance_level
    }

    # Jarque-Bera test
    jb_statistic, jb_pvalue = jarque_bera(data)
    ak08_results["Jarque-Bera"] = {"statistic": jb_statistic, "p-value": jb_pvalue}

    return ak08_results

# %%
from scipy import stats

# Test of Correlation (T-test)
def t_test_correlation(data1, data2):
    t_statistic, p_value = stats.ttest_ind(data1, data2)
    return {"t-statistic": t_statistic, "p-value": p_value}

for col in ak08_non_cat_vars:
    print(f"Normality tests for {col}:")
    normality_test_results = normality_tests(ak08_sample[col])
    for test_name, result in normality_test_results.items():
        print(f"  {test_name}: {result}")

    # Example of T-test
    if len(ak08_non_cat_vars) > 1:
        for i in range(len(ak08_non_cat_vars)):
            for j in range(i+1, len(ak08_non_cat_vars)):
                col1, col2 = ak08_non_cat_vars[i], ak08_non_cat_vars[j]
                t_test_result = t_test_correlation(ak08_sample[col1], ak08_sample[col2])
                print(f"T-test Correlation between {col1} and {col2}: {t_test_result}")
    print()
    print('*'*20)
    print()
# Out:
# Normality tests for Quantity:
#   Shapiro-Wilk: {'statistic': 0.9562216741765639, 'p-value': 2.4975566330260055e-36}
#   Kolmogorov-Smirnov: {'statistic': 0.5, 'p-value': 0.0}
#   Anderson-Darling: {'statistic': 52.866549766006756, 'critical_values': array([0.576, 0.655, 0.786, 0.917, 1.091]), 'significance_level': array([15. , 10. ,  5. ,  2.5,  1. ])}
#   Jarque-Bera: {'statistic': 292.5681536830006, 'p-value': 2.9487139027406343e-64}
# T-test Correlation between Quantity and Value: {'t-statistic': -0.32230552797841244, 'p-value': 0.74722798331054}
# T-test Correlation between Quantity and Weight: {'t-statistic': -0.3771227083194705, 'p-value': 0.7060904186656999}
# T-test Correlation between Value and Weight: {'t-statistic': -0.056141249541767024, 'p-value': 0.9552304049585267}
#
# ********************
#
# Normality tests for Value:
#   Shapiro-Wilk: {'statistic': 0.9567047987089498, 'p-value': 3.604136012808221e-36}
#   Kolmogorov-Smirnov: {'statistic': 0.5, 'p-value': 0.0}
# ...

# %% [markdown]
# ####**> Observations for Normality Tests for Quantity**
#
# **Shapiro-Wilk:** The p-value is extremely low, strongly rejecting normality for Quantity.
#
# **Kolmogorov-Smirnov:** The p-value of 0.0 provides strong evidence against normality for Quantity.
#
# **Anderson-Darling:** The high test statistic further confirms the non-normality of Quantity.
#
# **Jarque-Bera:** The extremely low p-value reinforces the rejection of normality for Quantity.
#
# **T-test (Quantity vs. Value):** No significant correlation is found between Quantity and Value.
#
# **T-test (Quantity vs. Weight):** No significant correlation is found between Quantity and Weight.

# %% [markdown]
# ####**> Observations for Normality Tests for Value**
#
# **Shapiro-Wilk:** The extremely low p-value strongly indicates that the Value data is not normally distributed.
#
# **Kolmogorov-Smirnov:** Similar to Shapiro-Wilk, the p-value of 0.0 leads to a strong rejection of normality for Value.
#
# **Anderson-Darling:** The high test statistic further supports the rejection of normality for the Value data.
#
# **Jarque-Bera:** The extremely low p-value provides strong evidence against the normality of the Value data.
#
# **T-test (Quantity vs. Value):** There is no statistically significant correlation between Quantity and Value.
#
# **T-test (Value vs. Weight):** There is no statistically significant correlation between Value and Weight.

# %% [markdown]
# ####**> Observations for Normality Tests for Weight**
#
# **Shapiro-Wilk:** With a p-value of 9.297755227475263e-37, the Shapiro-Wilk test strongly rejects normality for Weight.
#
# **Kolmogorov-Smirnov:** The p-value of 0.0 provides clear evidence against normality for Weight.
#
# **Anderson-Darling:** The high test statistic (55.70822617231897) further confirms the non-normality of Weight.
#
# **Jarque-Bera:** The extremely low p-value (6.596774074568189e-66) reinforces the rejection of normality for Weight.
#
# **T-test (Quantity vs. Weight):** With a t-statistic of -0.3771227083194705 and a p-value of 0.7060904186656999, there is no statistically significant correlation between Quantity and Weight.
#
# **T-test (Value vs. Weight):** With a t-statistic of -0.056141249541767024 and a p-value of 0.9552304049585267, there is no statistically significant correlation between Value and Weight.

# %% [markdown]
# #**Supervised Learning**

# %% [markdown]
# ### **Split into test and train dataset**

# %%
ak08_X = ak08_processed[['Quantity','Weight']]  # Features (excluding 'Cluster')
ak08_y = ak08_processed[['Shipping_Method']]  # Target variable

ak08_X_train, ak08_X_test, ak08_y_train, ak08_y_test = train_test_split(ak08_X, ak08_y, test_size=0.3, random_state=55008)

# Print the shapes of the resulting datasets
print("X_train shape:", ak08_X_train.shape)
print("X_test shape:", ak08_X_test.shape)
print("y_train shape:", ak08_y_train.shape)
print("y_test shape:", ak08_y_test.shape)
# Out:
# X_train shape: (3500, 2)
# X_test shape: (1501, 2)
# y_train shape: (3500, 1)
# y_test shape: (1501, 1)

# %% [markdown]
# ###**> Classification <**
#
# ###**Decision Tree**

# %%
# Initialize the Decision Tree Classifier
ak08_dt_classifier = DecisionTreeClassifier(criterion='gini', random_state=55008)

# Train the model
ak08_dt_classifier.fit(ak08_X_train, ak08_y_train)

# Make predictions on the test set
ak08_y_pred_dt = ak08_dt_classifier.predict(ak08_X_test)

# %%
# Evaluate the model
ak08_accuracy_dt = accuracy_score(ak08_y_test, ak08_y_pred_dt)
print(f"Decision Tree Accuracy: {ak08_accuracy_dt}")
print(classification_report(ak08_y_test, ak08_y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.31845436375749503
#               precision    recall  f1-score   support
#
#          0.0       0.32      0.37      0.34       487
#          1.0       0.30      0.29      0.29       494
#          2.0       0.34      0.30      0.32       520
#
#     accuracy                           0.32      1501
#    macro avg       0.32      0.32      0.32      1501
# weighted avg       0.32      0.32      0.32      1501

# %% [markdown]
# **Accuracy:**
#
# - The overall accuracy of the Decision Tree model is 0.32 (or 32%).
# - This indicates that the model correctly classified approximately 32% of the instances in the dataset.
#
# **Precision, Recall, and F1-Score (Class-wise):**
#
# - **Class 0.0:** Precision: 0.32, Recall: 0.37, F1-score: 0.34
#
# - **Class 1.0:** Precision: 0.30, Recall: 0.29, F1-score: 0.29
#
# - **Class 2.0:** Precision: 0.34, Recall: 0.30, F1-score: 0.32
#
# These metrics show that the model's performance is relatively consistent across all three classes, with Class 0.0 having slightly better recall and Class 1.0 the lowest F1-score.
#
#
# **Macro Average:**
#
# - Precision: 0.32, Recall: 0.32, F1-score: 0.32
# - The macro average considers the unweighted mean of the metrics across all classes, indicating a balanced but overall low performance.
#
# **Weighted Average:**
#
# - Precision: 0.32, Recall: 0.32, F1-score: 0.32
# - The weighted average takes into account the class distribution, reflecting the overall performance considering the proportion of each class in the dataset, which is also low.
#
# **Support:**
#
# - The support values indicate the number of instances belonging to each class: 487 for Class 0.0, 494 for Class 1.0, and 520 for Class 2.0.
#
#
# ### **Overall Observations:**
#
# - The Decision Tree model demonstrates a relatively low accuracy of 32%, suggesting limitations in its ability to effectively classify instances.
# - The consistent performance across classes, as reflected in the macro and weighted averages, indicates a balanced but suboptimal performance, with all metrics averaging around 32%.
# - While the model previously showed slightly better performance for Class 2.0, the updated data suggests that Class 0.0 now has slightly better recall (0.37), while Class 1.0 exhibits the lowest F1-score (0.29), indicating potential areas for improvement.

# %%
# Confusion matrix

ak08_cm = confusion_matrix(ak08_y_test, ak08_y_pred_dt)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(ak08_cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=ak08_dt_classifier.classes_, yticklabels=ak08_dt_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Decision Tree')
plt.show()

# %% [markdown]
# ### Observations:
#
# 1. **Cluster 0:**
#    - The model correctly classified **179** instances as belonging to Cluster 0 (True Positives).
#    - It misclassified **168** instances from Cluster 0 into Cluster 1 and **140** instances into Cluster 2 (False Negatives).
#    - This indicates a tendency to confuse Cluster 0 with both Cluster 1 and Cluster 2, with a slightly higher inclination towards misclassification into Cluster 1.
#
# 2. **Cluster 1:**
#    - The model correctly classified **187** instances as belonging to Cluster 1 (True Positives).
#    - It misclassified **142** instances from Cluster 1 into Cluster 0 and **165** instances into Cluster 2 (False Negatives).
#    - This suggests a relatively balanced misclassification pattern for Cluster 1, with similar tendencies to be confused with both Cluster 0 and Cluster 2.
#
# 3. **Cluster 2:**
#    - The model correctly classified **199** instances as belonging to Cluster 2 (True Positives).
#    - It misclassified **164** instances from Cluster 2 into Cluster 0 and **157** instances into Cluster 1 (False Negatives).
#    - This reveals a tendency to misclassify Cluster 2 instances into both Cluster 0 and Cluster 1, with a slightly higher inclination towards misclassification into Cluster 0.
#
# ### Overall:
#
# - The diagonal values (True Positives) are relatively high for all clusters, indicating good accuracy in cluster assignments.
# - The off-diagonal values (False Negatives) show some misclassifications, with a notable tendency to confuse clusters with each other.
# - However, compared to the previous analysis, the overall performance of the Decision Tree appears to have improved.

# %% [markdown]
# ###**K Nearest Neighbours**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report


# 2. Create and train the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors (k)
knn.fit(ak08_X_train, ak08_y_train)

# 3. Make predictions on the test set
y_pred = knn.predict(ak08_X_test)

# 4. Evaluate the model
ak08_accuracy_knn = accuracy_score(ak08_y_test, y_pred)
print(f"Accuracy: {ak08_accuracy_knn}")
print(classification_report(ak08_y_test, y_pred))
# Out:
# Accuracy: 0.3271152564956695
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.48      0.39       487
#          1.0       0.32      0.34      0.33       494
#          2.0       0.35      0.17      0.23       520
#
#     accuracy                           0.33      1501
#    macro avg       0.33      0.33      0.32      1501
# weighted avg       0.33      0.33      0.31      1501

# %% [markdown]
# ### **Observations:**
#
# **Low Accuracy:**
# The overall accuracy of 33% (rounded down from 32.71%) is relatively low, indicating that the model struggles to accurately classify instances across all classes.
#
# **Class-wise Performance:**
# - The model exhibits varying performance across the three classes.
# - **Class 0.0** has the highest recall (0.48) but lower precision (0.33), suggesting it correctly identifies a higher proportion of actual Class 0.0 instances but also includes more false positives.
# - **Class 1.0** shows relatively balanced precision (0.32) and recall (0.34), indicating a moderate ability to classify instances of this class.
# - **Class 2.0** has the highest precision (0.35) but the lowest recall (0.17), meaning it makes fewer false positive predictions for this class but misses a significant number of actual Class 2.0 instances.
#
# **Macro and Weighted Averages:**
# Both the macro and weighted averages of precision, recall, and F1-score are around 0.32-0.33, further confirming the model's suboptimal performance overall. This suggests that the model's performance is consistently low across all classes, and the class imbalance does not significantly affect the overall performance evaluation.

# %% [markdown]
# ### **Naive Bayes (NB)**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB  # Or MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, classification_report

# 2. Create and train the Naive Bayes classifier
nb = GaussianNB()  # Choose the appropriate NB type (GaussianNB, MultinomialNB, BernoulliNB)
nb.fit(ak08_X_train, ak08_y_train)

# 3. Make predictions on the test set
ak08_y_pred = nb.predict(ak08_X_test)

# 4. Evaluate the model
ak08_accuracy_nb = accuracy_score(ak08_y_test, ak08_y_pred)
print(f"Accuracy: {ak08_accuracy_nb}")
print(classification_report(ak08_y_test, ak08_y_pred))
# Out:
# Accuracy: 0.33710859427048634
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.47      0.39       487
#          1.0       0.34      0.50      0.41       494
#          2.0       0.39      0.06      0.10       520
#
#     accuracy                           0.34      1501
#    macro avg       0.35      0.34      0.30      1501
# weighted avg       0.35      0.34      0.29      1501

# %% [markdown]
# ### **Observations:**
#
# **Low Overall Accuracy:**
# The overall accuracy of 34% (rounded down from 33.71%) is relatively low, suggesting the model has limitations in its ability to classify instances correctly.
#
# **Poor Performance on Class 2.0:**
# The model exhibits extremely poor performance on Class 2.0, with very low recall (0.06) and F1-score (0.10), despite having the highest precision (0.39). This indicates a significant challenge in identifying instances belonging to this class, with the model likely missing a large number of true positives.
#
# **Varied Performance Across Classes:**
# The model shows varied performance across the three classes.
# - Class 0.0 has moderate precision (0.33) and recall (0.47).
# - Class 1.0 shows relatively better performance with moderate precision (0.34) and the highest recall (0.50).
# - Class 2.0, as mentioned, struggles with very low recall despite having the highest precision.
#
# **Imbalanced Macro Average:**
# The macro average highlights the imbalanced performance, primarily due to the poor results on Class 2.0, bringing down the average recall and F1-score.
#
# **Low Weighted Average F1-Score:**
# The weighted average F1-score is low (0.29), further confirming the model's suboptimal performance overall, taking into account the class distribution.

# %% [markdown]
# ##**Logistic Regression**

# %%
# Initialize the Logistic Regression model
ak08_logreg_classifier = LogisticRegression(random_state=55008)

# Train the model
ak08_logreg_classifier.fit(ak08_X_train, ak08_y_train)

# Make predictions on the test set
ak08_y_pred_logreg = ak08_logreg_classifier.predict(ak08_X_test)

# Evaluate the model
ak08_accuracy_logreg = accuracy_score(ak08_y_test, ak08_y_pred_logreg)
print(f"Logistic Regression Accuracy: {ak08_accuracy_logreg}")
print(classification_report(ak08_y_test, ak08_y_pred_logreg))
# Out:
# Logistic Regression Accuracy: 0.3324450366422385
#               precision    recall  f1-score   support
#
#          0.0       0.32      0.55      0.41       487
#          1.0       0.35      0.46      0.40       494
#          2.0       0.15      0.00      0.01       520
#
#     accuracy                           0.33      1501
#    macro avg       0.28      0.34      0.27      1501
# weighted avg       0.27      0.33      0.27      1501

# %% [markdown]
# ### **Observations:**
#
# **Low Overall Accuracy:** The overall accuracy of 33% (rounded down from 33.24%) is relatively low, indicating the model's limitations in accurately classifying instances.
#
# **Complete Failure on Class 2.0:** The model completely fails to identify instances belonging to Class 2.0, as indicated by near-zero recall (0.00) and F1-score (0.01), despite having a moderate precision of 0.15. This is a major concern and requires further investigation, suggesting potential issues with class imbalance or model limitations.
#
# **Varied Performance Across Classes:** The model shows varied performance across the remaining two classes.
# - Class 0.0 has moderate precision (0.32) and the highest recall (0.55) among all classes.
# - Class 1.0 shows relatively balanced performance with moderate precision (0.35) and recall (0.46).
#
# **Imbalanced Macro Average:** The macro average highlights the imbalanced performance due to the complete failure on Class 2.0, bringing down the average recall and F1-score significantly.
#
# **Low Weighted Average Precision and F1-Score:** The weighted average precision (0.27) and F1-score (0.27) are low, further confirming the model's suboptimal performance overall, taking into account the class distribution.

# %%
# Confusion Matrix for Logistic Regression
cm_logreg = confusion_matrix(ak08_y_test, ak08_y_pred_logreg)

# Plot the confusion matrix for Logistic Regression
plt.figure(figsize=(8, 6))
sns.heatmap(cm_logreg, annot=True, fmt='d', cmap='Greens',  # Different colormap
            xticklabels=ak08_logreg_classifier.classes_, yticklabels=ak08_logreg_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Logistic Regression')
plt.show()

# %% [markdown]
# ### Observations:
#
# **Cluster 0:**
#
# - The model correctly classified **268** instances as belonging to Cluster 0 (True Positives).
# - It misclassified **211** instances from Cluster 0 into Cluster 1 and **8** instances into Cluster 2 (False Negatives).
# - This suggests the model struggles to distinguish Cluster 0 from Cluster 1.
#
# **Cluster 1:**
#
# - The model correctly classified **262** instances as belonging to Cluster 1 (True Positives).
# - It misclassified **229** instances from Cluster 1 into Cluster 0 and **3** instances into Cluster 2 (False Negatives).
# - This suggests the model struggles to distinguish Cluster 1 from Cluster 0.
#
# **Cluster 2:**
#
# - The model correctly classified **304** instances as belonging to Cluster 2 (True Positives).
# - It misclassified **214** instances from Cluster 2 into Cluster 0 and **2** instances into Cluster 1 (False Negatives).
# - This suggests the model struggles to distinguish Cluster 2 from Cluster 0.
#
# ### Overall:
#
# - The diagonal values (True Positives) are relatively high for all clusters, indicating good accuracy in cluster assignments.
# - The off-diagonal values (False Negatives) show some misclassifications, particularly between Cluster 0 and Cluster 1.
# - Overall, the model seems to be performing well in classifying instances into their respective clusters.
#
# ### Insights:
#
# - The updated confusion matrix provides a positive outlook on the Logistic Regression model's performance.
# - While there are some misclassifications, the model demonstrates high accuracy in cluster assignments.
# - The insights from this analysis can be useful for further optimization and fine-tuning of the model.
# - It's crucial to consider the context and project goals when interpreting the confusion matrix and evaluating the model's suitability for the intended task.

# %% [markdown]
# ###**K-Fold Cross Validation for Logistic Regression**

# %%
# Initialize the Logistic Regression model
ak08_logreg_classifier = LogisticRegression(random_state=55008)

# Set up K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=55008)

# Perform Cross-Validation
cv_accuracy = cross_val_score(ak08_logreg_classifier, ak08_X_train, ak08_y_train, cv=kfold, scoring='accuracy')

# Output Cross-Validation results
print("K-Fold Cross-Validation Accuracy Scores: ", cv_accuracy)
print("Mean Accuracy: ", cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", cv_accuracy.std())

# Train the model on the entire training set (if needed for later use)
ak08_logreg_classifier.fit(ak08_X_train, ak08_y_train)

# Evaluate the model on the test set
ak08_y_pred_logreg = ak08_logreg_classifier.predict(ak08_X_test)
ak08_accuracy_logreg = accuracy_score(ak08_y_test, ak08_y_pred_logreg)
print(f"Logistic Regression Test Set Accuracy: {ak08_accuracy_logreg}")
print(classification_report(ak08_y_test, ak08_y_pred_logreg))
# Out:
# K-Fold Cross-Validation Accuracy Scores:  [0.32714286 0.33142857 0.35142857 0.33142857 0.33857143]
# Mean Accuracy:  0.33599999999999997
# Standard Deviation of Accuracy:  0.008542809364414896
# Logistic Regression Test Set Accuracy: 0.3324450366422385
#               precision    recall  f1-score   support
#
#          0.0       0.32      0.55      0.41       487
#          1.0       0.35      0.46      0.40       494
#          2.0       0.15      0.00      0.01       520
#
#     accuracy                           0.33      1501
#    macro avg       0.28      0.34      0.27      1501
# weighted avg       0.27      0.33      0.27      1501

# %% [markdown]
# ###**K-Fold Cross Validation for Support Vector Machine (SVM)**

# %%
from sklearn.svm import SVC
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import classification_report, accuracy_score

# Initialize the SVM model
ak08_svm_classifier = SVC(kernel='linear', random_state=55008)

# Set up K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=55008)

# Perform Cross-Validation
cv_accuracy = cross_val_score(ak08_svm_classifier, ak08_X_train, ak08_y_train, cv=kfold, scoring='accuracy')

# Output Cross-Validation results
print("K-Fold Cross-Validation Accuracy Scores: ", cv_accuracy)
print("Mean Accuracy: ", cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", cv_accuracy.std())

# Train the model on the entire training set (if needed for later use)
ak08_svm_classifier.fit(ak08_X_train, ak08_y_train)

# Evaluate the model on the test set
ak08_y_pred_svm = ak08_svm_classifier.predict(ak08_X_test)
ak08_accuracy_svm = accuracy_score(ak08_y_test, ak08_y_pred_svm)
print(f"SVM Test Set Accuracy: {ak08_accuracy_svm}")
print(classification_report(ak08_y_test, ak08_y_pred_svm))
# Out:
# K-Fold Cross-Validation Accuracy Scores:  [0.33       0.33571429 0.33142857 0.34571429 0.33      ]
# Mean Accuracy:  0.3345714285714286
# Standard Deviation of Accuracy:  0.005952190473142749
# SVM Test Set Accuracy: 0.3344437041972019
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.53      0.40       487
#          1.0       0.34      0.49      0.41       494
#          2.0       0.00      0.00      0.00       520
#
#     accuracy                           0.33      1501
#    macro avg       0.22      0.34      0.27      1501
# weighted avg       0.22      0.33      0.26      1501

# %% [markdown]
# ###**K-Fold Cross Validation for Stochastic Gradient Descent (SGD)**

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import KFold, cross_val_score

# 1. Initialize the SGD Classifier
ak08_sgd_classifier = SGDClassifier(loss='log_loss', random_state=55008, max_iter=1000, tol=1e-3)
# Changed 'log' to 'log_loss' for logistic regression

# 2. Set up K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=55008)

# 3. Perform Cross-Validation
cv_accuracy = cross_val_score(ak08_sgd_classifier, ak08_X_train, ak08_y_train, cv=kfold, scoring='accuracy')

# 4. Output Cross-Validation Results
print("K-Fold Cross-Validation Accuracy Scores: ", cv_accuracy)
print("Mean Accuracy: ", cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", cv_accuracy.std())

# 5. Train the SGD Classifier on the entire training set
ak08_sgd_classifier.fit(ak08_X_train, ak08_y_train)

# 6. Make predictions on the test set
ak08_y_pred_sgd = ak08_sgd_classifier.predict(ak08_X_test)

# 7. Evaluate the Model
ak08_accuracy_sgd = accuracy_score(ak08_y_test, ak08_y_pred_sgd)
print(f"SGD Test Set Accuracy: {ak08_accuracy_sgd}")
print(classification_report(ak08_y_test, ak08_y_pred_sgd))
# Out:
# K-Fold Cross-Validation Accuracy Scores:  [0.35       0.34       0.30285714 0.32857143 0.35285714]
# Mean Accuracy:  0.33485714285714285
# Standard Deviation of Accuracy:  0.01812879094767463
# SGD Test Set Accuracy: 0.3291139240506329
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       487
#          1.0       0.33      1.00      0.50       494
#          2.0       0.00      0.00      0.00       520
#
#     accuracy                           0.33      1501
#    macro avg       0.11      0.33      0.17      1501
# weighted avg       0.11      0.33      0.16      1501

# %% [markdown]
# ###**Comparison of LR vs SVM**

# %%
print(f"Logistic Regression Accuracy: {ak08_accuracy_logreg}")
print(f"SVM Accuracy: {ak08_accuracy_svm}")

if ak08_accuracy_logreg > ak08_accuracy_svm:
    print("Logistic Regression model performs better.")
elif ak08_accuracy_svm > ak08_accuracy_logreg:
    print("Support Vector Machine model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Logistic Regression Accuracy: 0.3324450366422385
# SVM Accuracy: 0.3344437041972019
# Support Vector Machine model performs better.

# %% [markdown]
# ###**Comparison of LR vs SGD**

# %%
print(f"Logistic Regression Accuracy: {ak08_accuracy_logreg}")
print(f"SGD Accuracy: {ak08_accuracy_sgd}")

if ak08_accuracy_logreg > ak08_accuracy_sgd:
    print("Logistic Regression model performs better.")
elif ak08_accuracy_sgd > ak08_accuracy_logreg:
    print("Stochastic Gradient Descent model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Logistic Regression Accuracy: 0.3324450366422385
# SGD Accuracy: 0.3291139240506329
# Logistic Regression model performs better.

# %% [markdown]
# ###**Comparison of DT vs KNN**

# %%
print(f"Decision Tree Accuracy: {ak08_accuracy_dt}")
print(f"KNN Accuracy: {ak08_accuracy_knn}")

if ak08_accuracy_dt > ak08_accuracy_knn:
    print("Decision Tree model performs better.")
elif ak08_accuracy_knn > ak08_accuracy_dt:
    print("K Nearest Neighbour model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.31845436375749503
# KNN Accuracy: 0.3271152564956695
# K Nearest Neighbour model performs better.

# %% [markdown]
# ###**Comparison of LR vs DT**

# %%
print(f"Logistic Regression Accuracy: {ak08_accuracy_logreg}")
print(f"Decision Tree Accuracy: {ak08_accuracy_dt}")

if ak08_accuracy_logreg > ak08_accuracy_dt:
    print("Logistic Regression model performs better.")
elif ak08_accuracy_dt > ak08_accuracy_logreg:
    print("Decision Tree model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Logistic Regression Accuracy: 0.3324450366422385
# Decision Tree Accuracy: 0.31845436375749503
# Logistic Regression model performs better.

# %% [markdown]
# ###**Comparison of DT vs NB**

# %%
print(f"Decision Tree Accuracy: {ak08_accuracy_dt}")
print(f"Naive Bayes Accuracy: {ak08_accuracy_nb}")

if ak08_accuracy_dt > ak08_accuracy_nb:
    print("Decision Tree model performs better.")
elif ak08_accuracy_nb > ak08_accuracy_dt:
    print("Naive Bayes model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.31845436375749503
# Naive Bayes Accuracy: 0.33710859427048634
# Naive Bayes model performs better.

# %% [markdown]
# ##**Random Forest**

# %%
# Initialize the Random Forest Classifier
ak08_rf_classifier = RandomForestClassifier(random_state=55008)

# Train the model
ak08_rf_classifier.fit(ak08_X_train, ak08_y_train)

# Make predictions on the test set
ak08_y_pred_rf = ak08_rf_classifier.predict(ak08_X_test)

# Evaluate the model
ak08_accuracy_rf = accuracy_score(ak08_y_test, ak08_y_pred_rf)
print(f"Random Forest Accuracy: {ak08_accuracy_rf}")
print(classification_report(ak08_y_test, ak08_y_pred_rf))
# Out:
# Random Forest Accuracy: 0.31645569620253167
#               precision    recall  f1-score   support
#
#          0.0       0.31      0.36      0.33       487
#          1.0       0.31      0.31      0.31       494
#          2.0       0.34      0.28      0.31       520
#
#     accuracy                           0.32      1501
#    macro avg       0.32      0.32      0.32      1501
# weighted avg       0.32      0.32      0.32      1501

# %%
# Confusion Matrix for Random Forest
ak08_cm_rf = confusion_matrix(ak08_y_test, ak08_y_pred_rf)

# Plot the confusion matrix for Random Forest
plt.figure(figsize=(8, 6))
sns.heatmap(ak08_cm_rf, annot=True, fmt='d', cmap='Oranges',  # Different colormap
            xticklabels=ak08_rf_classifier.classes_, yticklabels=ak08_rf_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Random Forest')
plt.show()

# %% [markdown]
# ### Observations:
#
# **1. Cluster 0:**
#
# - The model correctly classified **175** instances as belonging to Cluster 0 (True Positives).
# - It misclassified **179** instances from Cluster 0 into Cluster 1 and **133** instances into Cluster 2 (False Negatives).
# - This indicates a tendency to confuse Cluster 0 with both Cluster 1 and Cluster 2.
#
# **2. Cluster 1:**
#
# - The model correctly classified **186** instances as belonging to Cluster 1 (True Positives).
# - It misclassified **152** instances from Cluster 1 into Cluster 0 and **156** instances into Cluster 2 (False Negatives).
# - This suggests a relatively balanced misclassification pattern for Cluster 1, with similar tendencies to be confused with both Cluster 0 and Cluster 2.
#
# **3. Cluster 2:**
#
# - The model correctly classified **206** instances as belonging to Cluster 2 (True Positives).
# - It misclassified **166** instances from Cluster 2 into Cluster 0 and **148** instances into Cluster 1 (False Negatives).
# - This reveals a tendency to misclassify Cluster 2 instances into both Cluster 0 and Cluster 1.
#
# ### Overall:
#
# - The diagonal values (True Positives) are relatively high for all clusters, indicating good accuracy in cluster assignments.
# - The off-diagonal values (False Negatives) show some misclassifications, with a notable tendency to confuse clusters with each other.
# - However, compared to some other models, the Random Forest model seems to have a relatively balanced performance in terms of misclassifications across clusters.
#
# ### Insights:
#
# - The updated confusion matrix provides a positive outlook on the Random Forest model's performance.
# - The model still exhibits some misclassification, but the overall accuracy is relatively high.
# - The insights from this analysis can be useful for further optimization and fine-tuning of the model.
# - It's crucial to consider the context and project goals when interpreting the confusion matrix and evaluating the model's suitability for the intended task.

# %% [markdown]
# ###**Extreme Gradient Boosting**

# %%
ak08_clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
    max_depth=1, random_state=55008).fit(ak08_X_train, ak08_y_train)
print("The mean accuracy on the given test data and labels from Extreme Gradient Boosting is",ak08_clf.score(ak08_X_test, ak08_y_test))
# Out:
# The mean accuracy on the given test data and labels from Extreme Gradient Boosting is 0.32978014656895405

# %% [markdown]
# ### **Observation**
#
# The mean accuracy of 0.33 (rounded down from 0.32978014656895405) suggests that the XGBoost model, on average, correctly classifies approximately 33% of the instances in the given test data. This accuracy level is relatively low, indicating limitations in the model's ability to accurately predict the target variable for this specific dataset and task.

# %% [markdown]
# ###**Comparison of RF vs DT**

# %%
# Compare Random Forest and Decision Tree

print(f"\nDecision Tree Accuracy: {ak08_accuracy_dt}")
print(f"Random Forest Accuracy: {ak08_accuracy_rf}")

if ak08_accuracy_rf > ak08_accuracy_dt:
    print("Random Forest performs better than Decision Tree.")
elif ak08_accuracy_dt > ak08_accuracy_rf:
    print("Decision Tree performs better than Random Forest.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.31845436375749503
# Random Forest Accuracy: 0.31645569620253167
# Decision Tree performs better than Random Forest.

# %% [markdown]
# ###**Model Run Statistics**

# %% [markdown]
# ####**Time Taken**

# %%
import time
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

def time_model_run(model, X_train, y_train):
    start_time = time.time()
    model.fit(X_train, y_train)
    end_time = time.time()
    return end_time - start_time

# Logistic Regression
log_reg_model = LogisticRegression(random_state=55008)
log_reg_time = time_model_run(log_reg_model, ak08_X_train, ak08_y_train)
print(f"Logistic Regression runtime: {log_reg_time:.4f} seconds")

# Support Vector Machine (SVM)
svm_model = SVC(random_state=55008)
svm_time = time_model_run(svm_model, ak08_X_train, ak08_y_train)
print(f"SVM runtime: {svm_time:.4f} seconds")

# Stochastic Gradient Descent (SGD)
sgd_model = SGDClassifier(random_state=55008)
sgd_time = time_model_run(sgd_model, ak08_X_train, ak08_y_train)
print(f"SGD runtime: {sgd_time:.4f} seconds")

# Decision Tree
dt_model = DecisionTreeClassifier(random_state=55008)
dt_time = time_model_run(dt_model, ak08_X_train, ak08_y_train)
print(f"Decision Tree runtime: {dt_time:.4f} seconds")

# K-Nearest Neighbors (KNN)
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_time = time_model_run(knn_model, ak08_X_train, ak08_y_train)
print(f"KNN runtime: {knn_time:.4f} seconds")

# Naive Bayes
nb_model = GaussianNB()
nb_time = time_model_run(nb_model, ak08_X_train, ak08_y_train)
print(f"Naive Bayes runtime: {nb_time:.4f} seconds")

# Random Forest
rf_model = RandomForestClassifier(random_state=55008)
rf_time = time_model_run(rf_model, ak08_X_train, ak08_y_train)
print(f"Random Forest runtime: {rf_time:.4f} seconds")

# Extreme Gradient Boosting (XGBoost)
xgb_model = XGBClassifier(random_state=55008)
xgb_time = time_model_run(xgb_model, ak08_X_train, ak08_y_train)
print(f"XGBoost runtime: {xgb_time:.4f} seconds")
# Out:
# Logistic Regression runtime: 0.0157 seconds
# SVM runtime: 1.3681 seconds
# SGD runtime: 0.0496 seconds
# Decision Tree runtime: 0.0307 seconds
# KNN runtime: 0.0066 seconds
# Naive Bayes runtime: 0.0052 seconds
# Random Forest runtime: 4.7364 seconds
# XGBoost runtime: 1.3385 seconds

# %% [markdown]
# ### **Observations:**
#
# - Fastest: KNN (0.0049 seconds) and Naive Bayes (0.0040 seconds) are the fastest, taking less than 0.01 seconds.
# - Slowest: Random Forest (1.0186 seconds) is the slowest, taking over 1 second.
# - Moderate: Logistic Regression (0.0098 seconds), Decision Tree (0.0235 seconds), and SGD (0.0306 seconds) have moderate runtimes, ranging from approximately 0.01 to 0.03 seconds.
# - Relatively Slow: SVM (0.5146 seconds) and XGBoost (0.3291 seconds) are relatively slow, taking around 0.5 seconds and 0.3 seconds, respectively.
#
#
# #### **Insights:**
#
# - KNN and Naive Bayes are the fastest, ideal for quick analysis and initial exploration, especially with limited computational resources.
# - Logistic Regression, Decision Tree, and SGD offer moderate speed and complexity, providing a balance between performance and efficiency.
# - Random Forest, while potentially more accurate and robust, is the slowest, requiring more computational time and resources for training.
# - SVM and XGBoost have relatively slower runtimes compared to the faster models, but they can offer better performance for complex datasets with non-linear relationships.

# %% [markdown]
# ####**Memory Utilized**

# %%
import tracemalloc
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

def get_model_memory_usage(model, X, y):
    tracemalloc.start()
    model.fit(X, y)
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    return peak / (1024 * 1024)  # Convert bytes to MB

# Logistic Regression
log_reg_model = LogisticRegression(random_state=55008)
log_reg_memory = get_model_memory_usage(log_reg_model, ak08_X_train, ak08_y_train)
print(f"Logistic Regression memory usage: {log_reg_memory:.2f} MB")

# Support Vector Machine (SVM)
svm_model = SVC(random_state=55008)
svm_memory = get_model_memory_usage(svm_model, ak08_X_train, ak08_y_train)
print(f"SVM memory usage: {svm_memory:.2f} MB")

# Stochastic Gradient Descent (SGD)
sgd_model = SGDClassifier(random_state=55008)
sgd_memory = get_model_memory_usage(sgd_model, ak08_X_train, ak08_y_train)
print(f"SGD memory usage: {sgd_memory:.2f} MB")

# Decision Tree
dt_model = DecisionTreeClassifier(random_state=55008)
dt_memory = get_model_memory_usage(dt_model, ak08_X_train, ak08_y_train)
print(f"Decision Tree memory usage: {dt_memory:.2f} MB")

# K-Nearest Neighbors (KNN)
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_memory = get_model_memory_usage(knn_model, ak08_X_train, ak08_y_train)
print(f"KNN memory usage: {knn_memory:.2f} MB")

# Naive Bayes
nb_model = GaussianNB()
nb_memory = get_model_memory_usage(nb_model, ak08_X_train, ak08_y_train)
print(f"Naive Bayes memory usage: {nb_memory:.2f} MB")

# Random Forest
rf_model = RandomForestClassifier(random_state=55008)
rf_memory = get_model_memory_usage(rf_model, ak08_X_train, ak08_y_train)
print(f"Random Forest memory usage: {rf_memory:.2f} MB")

# Extreme Gradient Boosting (XGBoost)
xgb_model = XGBClassifier(random_state=55008)
xgb_memory = get_model_memory_usage(xgb_model, ak08_X_train, ak08_y_train)
print(f"XGBoost memory usage: {xgb_memory:.2f} MB")
# Out:
# Logistic Regression memory usage: 0.34 MB
# SVM memory usage: 0.26 MB
# SGD memory usage: 0.18 MB
# Decision Tree memory usage: 0.22 MB
# KNN memory usage: 0.22 MB
# Naive Bayes memory usage: 0.11 MB
# Random Forest memory usage: 0.45 MB
# XGBoost memory usage: 0.89 MB

# %% [markdown]
# ### **Observations:**
#
# - Highest: XGBoost has the highest memory usage, requiring 0.88 MB.
# - Lowest: Naive Bayes has the lowest memory usage, requiring only 0.11 MB.
# - Moderate: Logistic Regression (0.34 MB), Decision Tree (0.23 MB), KNN (0.22 MB), Random Forest (0.57 MB), and SVM (0.25 MB) have moderate memory usage, ranging from approximately 0.22 MB to 0.57 MB.
# - Relatively Low: SGD has relatively low memory usage, requiring 0.18 MB.
#
#
# #### **Insights:**
#
# - XGBoost has the highest memory usage, requiring careful resource management, especially when working with large datasets or limited memory environments.
# - Random Forest also has relatively high memory usage (0.57 MB) compared to other models, due to its ensemble nature and storing multiple decision trees.
# - Logistic Regression (0.34 MB), Decision Tree (0.23 MB), and KNN (0.22 MB) have moderate memory requirements, generally suitable for most tasks without significant memory constraints.
# - SVM (0.25 MB) and SGD (0.18 MB) have lower memory usage, making them suitable for resource-constrained environments or when memory efficiency is a priority.
# - Naive Bayes has the lowest memory footprint (0.11 MB), ideal for memory-sensitive tasks or when working with very large datasets.

# %% [markdown]
# ---
